# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-contrib", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/site-packages/jupyter_core/application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/traitlets/config/application.py", line 1051, in launch_instance
#     app = cls.instance(**kwargs)
#   File "/usr/local/lib/python3.8/site-packages/traitlets/config/configurable.py", line 575, in instance
#     inst = cls(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/jupyter_contrib_core/application.py", line 27, in __init__
#     self._refresh_subcommands()
#   File "/usr/local/lib/python3.8/site-packages/jupyter_contrib_core/application.py", line 43, in _refresh_subcommands
#     get_subcommands_dict = entrypoint.load()
#   File "/usr/local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2450, in load
#     return self.resolve()
#   File "/usr/local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2456, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#   File "/usr/local/lib/python3.8/site-packages/jupyter_contrib_nbextensions/__init__.py", line 5, in <module>
#     import jupyter_nbextensions_configurator
#   File "/usr/local/lib/python3.8/site-packages/jupyter_nbextensions_configurator/__init__.py", line 18, in <module>
#     from notebook.base.handlers import APIHandler, IPythonHandler
# ModuleNotFoundError: No module named 'notebook.base'

# %%
import os
import math
import sys
import stat

import geopandas as gpd
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from osgeo import osr
import shapely
from plpygis import Geometry
from shapely.geometry import (
    LineString,
    MultiLineString,
    MultiPoint,
    MultiPolygon,
    Point,
    Polygon,
)

import flopy
import flopy.discretization as fgrid
import flopy.plot as fplot
from flopy.utils import GridIntersect, Raster
from flopy.utils.gridgen import Gridgen
wd = "./novgorod"
input_directory = os.path.join(wd, "input")

# %%
def raster_resample(path, modelgrid):
    rio = Raster.load(path)
    data = rio.resample_to_grid(modelgrid, band=rio.bands[0], method="nearest")
    return data

# %%
srs = osr.SpatialReference()
srs.ImportFromWkt('PROJCS["unknown",GEOGCS["GCS_unknown",DATUM["D_Unknown_based_on_Krassovsky_1942_ellipsoid",SPHEROID["Krassovsky_1942",6378245.0,298.3]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",2250000.0],PARAMETER["False_Northing",-5714743.504],PARAMETER["Central_Meridian",44.55],PARAMETER["Scale_Factor",1.0],PARAMETER["Latitude_Of_Origin",0.0],UNIT["Meter",1.0]]')
proj_string = srs.ExportToProj4()

# %%
# Load a polygon shapefile
boundary = gpd.read_file(os.path.join(input_directory, "vectors", "boundary.shp"), crs=proj_string)
boudary_json = boundary.to_json()
# Out:
# /tmp/ipykernel_25/1912189973.py:3: UserWarning: GeoDataFrame's CRS is not representable in URN OGC format. Resulting JSON will contain no CRS information.
#   boudary_json = boundary.to_json()

# %%
nlay = 1
cell_size = 500
buffer = 2000
minx, miny, maxx, maxy = boundary.bounds.minx[0] - buffer, boundary.bounds.miny[0] - buffer, boundary.bounds.maxx[0] + buffer, boundary.bounds.maxy[0] + buffer
n_row = math.ceil((maxx - minx) / cell_size)
n_col = math.ceil((maxy - miny) / cell_size)
delr =  cell_size * np.ones(n_row, dtype=float)
delc =  cell_size * np.ones(n_col, dtype=float)

# %%
raster_ws = os.path.join(input_directory, "rasters")
# dem_name = "fabdem.tif"
dem_name = "Relief_new"

rio = Raster.load(os.path.join(raster_ws, dem_name))
arr = rio.get_array(1)
idx = np.isfinite(arr)
vmin, vmax = arr[idx].min(), arr[idx].max()

# %%
name = "nn"
exe_name = os.path.join("bin", "mf6")
workspace = os.path.join(wd, "model")
st = os.stat(exe_name)
os.chmod(exe_name, st.st_mode | stat.S_IEXEC)
sim = flopy.mf6.MFSimulation(
    sim_name=name, exe_name=exe_name, version="mf6", sim_ws=workspace
)

# Create the Flopy temporal discretization object
tdis = flopy.mf6.modflow.mftdis.ModflowTdis(
    sim, pname="tdis", time_units="DAYS", nper=1, perioddata=[(1.0, 1, 1.0)]
)

# Create the Flopy groundwater flow (gwf) model object
model_nam_file = "{}.nam".format(name)
gwf = flopy.mf6.ModflowGwf(sim, modelname=name, model_nam_file=model_nam_file)

# Create the Flopy iterative model solver (ims) Package object
ims = flopy.mf6.modflow.mfims.ModflowIms(sim, pname="ims", complexity="SIMPLE") #SIMPLE

# %%
ms = flopy.modflow.Modflow()
dis = flopy.modflow.ModflowDis(
    ms,
    nlay=nlay,
    nrow=n_col,
    ncol=n_row,
    delr=delr,
    delc=delc,
    top=0,
    botm=-10,
    crs=proj_string,
    xul=minx,
    yul=maxy
)
gridgen_ws = os.path.join(workspace, "grid")
gridgen_exe = os.path.join("bin", "gridgen")
st = os.stat(gridgen_exe)
os.chmod(gridgen_exe, st.st_mode | stat.S_IEXEC)
g = Gridgen(ms.modelgrid, model_ws=gridgen_ws, exe_name=gridgen_exe)
active_domain = Geometry(boundary.geometry.to_wkb()[0]).geojson["coordinates"]
g.add_active_domain([active_domain], [0])
# Out:
# /usr/local/lib/python3.8/site-packages/flopy/mbase.py:96: UserWarning: The program mf2005 does not exist or is not executable.
#   warn(

# %%
small_riv_gdf = gpd.read_file(os.path.join(input_directory, 'vectors', 'zones_small_river.shp'), crs=proj_string)
refine_level = 3
for river in small_riv_gdf.geometry.to_wkb():
    line = [Geometry(river).geojson["coordinates"]]
    g.add_refinement_features(line, "line", refine_level, [0])


riv_gdf = gpd.read_file(os.path.join(input_directory, 'vectors', 'zones_river.shp'), crs=proj_string)
riv_gdf = riv_gdf.explode()
refine_level = 3
for river in riv_gdf.geometry.to_wkb():
    poly = [Geometry(river).geojson["coordinates"]]
    g.add_refinement_features(poly, "polygon", refine_level, [0])
# Out:
# /tmp/ipykernel_25/3054382126.py:9: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   riv_gdf = riv_gdf.explode()

# %%
flood = gpd.read_file(os.path.join(input_directory, 'vectors', "flood_zone.shp"), crs=proj_string)
for zone in flood.geometry.to_wkb():
    line = Geometry(zone).geojson["coordinates"]
    g.add_refinement_features(line, "polygon", 2, [0])

# %%
g.build(verbose=False)

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, aspect="equal")
g.plot(ax, linewidth=0.5)

# %%
small_river_cells = []
for zn, river in enumerate(small_riv_gdf.geometry.to_wkb()):
    line = [Geometry(river).geojson["coordinates"]]
    cellids = g.intersect(line, 'line', 0)
    small_river_cells.append([cellids, zn])
river_cells = []
for zn, river in enumerate(riv_gdf.geometry.to_wkb()):
    poly = [Geometry(river).geojson["coordinates"]]
    cellids = g.intersect(poly, 'polygon', 0)
    river_cells.append([cellids, zn + 20])

# %%
gridprops = g.get_gridprops_disv()
ncpl = gridprops["ncpl"]
top = gridprops["top"]
botm = gridprops["botm"]
nvert = gridprops["nvert"]
vertices = gridprops["vertices"]
cell2d = gridprops["cell2d"]
disv = flopy.mf6.modflow.mfgwfdisv.ModflowGwfdisv(
    gwf,
    nlay=nlay,
    ncpl=ncpl,
    top=top,
    botm=botm,
    nvert=nvert,
    vertices=vertices,
    cell2d=cell2d,
    xorigin=minx, yorigin=miny, angrot=0
)
# Out:
# WARNING: Unable to resolve dimension of ('gwf6', 'disv', 'cell2d', 'cell2d', 'icvert') based on shape "ncvert".

# %%
modelgrid = gwf.modelgrid
dem_data = rio.resample_to_grid(
    modelgrid, band=rio.bands[0], method="nearest"
)

# %%
bot_data = raster_resample(os.path.join(input_directory, "rasters", "bot.tif"), modelgrid)
bot_data = np.where(dem_data - bot_data < 7, dem_data - 7, bot_data)
disv.top = dem_data
disv.botm = bot_data

# %%
# IC
ic = flopy.mf6.modflow.mfgwfic.ModflowGwfic(gwf, pname="ic", strt=dem_data)

# %%
npf = flopy.mf6.modflow.mfgwfnpf.ModflowGwfnpf(
    gwf, pname="npf", icelltype=1, k=9.36, save_flows=True
)

# %%
gen_icpl = []
river_stress_data = []

for river in small_river_cells:
    zn = river[1]
    for data in river[0]:
        icpl = data[0]
        length = data[2]
        if icpl >= 0 and icpl not in gen_icpl:
            gen_icpl.append(icpl)
            stage = disv.top[icpl]
            conductance = 100
            # conductance = 100
            river_stress_data.append([(0, icpl), stage, conductance, stage - 1.5, f"zn_{zn}"])

for river in river_cells:
    zn = river[1]
    for data in river[0]:
        icpl = data[0]
        length = data[2]
        if icpl >= 0 and icpl not in gen_icpl:
            gen_icpl.append(icpl)
            stage = disv.top[icpl]
            conductance = 1000
            # conductance = 2500
            river_stress_data.append([(0, icpl), stage, conductance, stage - 5, f"zn_{zn}"])
riv = flopy.mf6.modflow.mfgwfriv.ModflowGwfriv(gwf, stress_period_data=river_stress_data, save_flows=True, boundnames=True)

# %%
rch_spd = {0: 0.0002225}
rch = flopy.mf6.ModflowGwfrcha(
    gwf, readasarrays=True, pname="rch", print_input=True, recharge=rch_spd
)

# %%
drn_std = [ [(0, cell[0]), top, 10000] for cell, top in zip(disv.cell2d.array, disv.top.array)]

# %%
drn = flopy.mf6.ModflowGwfdrn(
    gwf, print_input=True, print_flows=True, stress_period_data=drn_std
)

# %%
# OBS
obsdict = {}
obslist = []
wells_wtd = pd.read_csv(os.path.join(input_directory, "vectors", "well_regime_sort2.csv"))
for index, well in wells_wtd.iterrows():
    wells_geom = [[float(well.X), float(well.Y)]]
    node = g.intersect(wells_geom, "point", 0)
    obslist.append((f"h_{well.id1}", "HEAD", (0, node[0][0])))
    
obsdict["{}.obs.head.csv".format(name)] = obslist
obs = flopy.mf6.ModflowUtlobs(
    gwf, print_input=True, continuous=obsdict
)

# %%
# output control
oc = flopy.mf6.ModflowGwfoc(
    gwf,
    pname="oc",
    budget_filerecord=f"{name}.cbb",
    head_filerecord=f"{name}.hds",
    headprintrecord=[("COLUMNS", 10, "WIDTH", 15, "DIGITS", 6, "GENERAL")],
    saverecord=[("HEAD", "ALL"), ("BUDGET", "ALL")],
    printrecord=[("HEAD", "ALL"), ("BUDGET", "ALL")],
)

# %%
# Write the datasets
sim.set_all_data_external(True)
sim.write_simulation()
# Run the simulation
success, buff = sim.run_simulation()
if success:
    for line in buff:
        print(line)
else:
    raise ValueError("Failed to run.")
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims...
#   writing model nn...
#     writing model name file...
#     writing package disv...
#     writing package ic...
#     writing package npf...
#     writing package riv_0...
# INFORMATION: maxbound in ('gwf6', 'riv', 'dimensions') changed to 55839 based on size of stress_period_data
#     writing package rch...
#     writing package drn_0...
# INFORMATION: maxbound in ('gwf6', 'drn', 'dimensions') changed to 129782 based on size of stress_period_data
#     writing package obs_0...
#     writing package oc...
# FloPy is using the following executable to run the model: ../../bin/mf6
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 03/08/2022
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Mar 08 2022 20:13:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.5.0
#                              Build 20211109_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 23:24:07
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 23:24:15
#  Elapsed run time:  8.033 Seconds
#
#  Normal termination of simulation.

# %%
headfile = f"{name}.hds"
fname = os.path.join(workspace, headfile)
hds = flopy.utils.HeadFile(fname)
head = hds.get_data()
levels = np.arange(0, 200, 10)
fig = plt.figure(figsize=(12, 12))

ax = fig.add_subplot(1, 1, 1)
pmv = flopy.plot.PlotMapView(modelgrid=modelgrid, ax=ax)
pmv.plot_array(head, alpha=0.2)
pmv.plot_grid(alpha=0.2)
contour = pmv.contour_array(head, levels=levels)
plt.clabel(contour, inline=True, fontsize=8, fmt='%1.0f')
contour = pmv.contour_array(head, levels=levels)
plt.clabel(contour, inline=True, fontsize=8, fmt='%1.0f')
# Out:
# <a list of 17 text.Text objects>

# %%
boundary = gpd.read_file('novgorod/input/vectors/boundary.shp', crs=proj_string)
CRS = boundary.crs
bounds = boundary.bounds
range_x = bounds.maxx[0] - bounds.minx[0]
range_y = bounds.maxy[0] - bounds.miny[0]
num_cells_x = int(range_x / 500)
num_cells_y = int(range_y / 500)

cell2d = m.disv.cell2d.get_data()
centroids_x = [cell[1] for cell in cell2d]
centroids_y = [cell[2] for cell in cell2d]

# Define grid_x and grid_y
gridx, gridy = np.meshgrid(np.linspace(bounds.minx[0], bounds.maxx[0], num=num_cells_x),
                           np.linspace(bounds.miny[0], bounds.maxy[0], num=num_cells_y))
transform = from_origin(gridx.min(), gridy.max(), 500, 500)
# Original coordinates
original_coords = np.array([centroids_x, centroids_y]).T  # x_coordinates and y_coordinates should be 1D arrays containing the x and y coordinates of your original data points respectively.

# Interpolate data
interpolated_data = griddata(original_coords, head.flatten(), (gridx, gridy), method='linear')  # 'nearest', 'linear', or 'cubic' interpolation methods can be used depending on the data.

# Now use interpolated_data with rasterio
new_dataset = rasterio.open(
    "head_drn.tif",
    'w',
    driver='GTiff',
    height=interpolated_data.shape[0],
    width=interpolated_data.shape[1],
    count=1,
    dtype=str(interpolated_data.dtype),
    nodata=np.nan,
    crs=CRS,
    transform=transform,
)
new_dataset.write(interpolated_data[::-1], 1)
new_dataset.close()

# %%
obs_prp = wells_wtd
# obs_prp = pd.read_csv("./sources/well_regime.csv", delimiter=';')
obs_prp["well"] = "H_" + obs_prp["id1"].astype(str)
obs_prp["time"] = 1.0
table_obs = pd.pivot_table(obs_prp, values='elevation', index='time',
                       columns=['well'], aggfunc=np.min)
table_obs = table_obs.reset_index()
table_obs.to_csv(os.path.join(workspace, f"{name}.obs.head.csv"), index=False)

# %%
zone_kf_gdf = gpd.read_file(os.path.join(input_directory, "vectors", "zone_kf.shp"), crs=proj_string)
zone_kf_gdf.head()
zones_kf = []
df = pd.DataFrame(columns=["icpl", "zone"])
for zn, zn_kf in enumerate(zone_kf_gdf.geometry.to_wkb()):
    poly = [Geometry(zn_kf).geojson["coordinates"]]
    cellids = g.intersect(poly, 'polygon', 0)
    df_temp = pd.DataFrame()
    df_temp["icpl"] = cellids["nodenumber"]
    df_temp["zone"] = zn + 1
    df = pd.concat([df, df_temp])
df_fin = df.drop_duplicates(subset=["icpl"], keep="first")
df_fin.to_csv(os.path.join(input_directory, "vectors", "zones_kf.csv"), index=False)

# %%
df_fin = pd.read_csv(os.path.join(input_directory, "vectors", "zones_kf.csv"))
zone_kf = df_fin.sort_values(by=["icpl"])["zone"].to_numpy()

# %%
import pp_alg
polygon = boundary.geometry.values[0]
points = pd.read_csv(os.path.join(input_directory, "vectors", "well_regime_sort2.csv"))
existing_points = [(x, y) for x, y in zip(points.X, points.Y)]
# Example usage
new_points = np.array(pp_alg.generate_points_within_polygon(polygon, existing_points, grid_spacing=10000, min_distance=2500))
new_points = [Point(x, y) for x, y in zip(new_points[:, 0], new_points[:, 1])]
# points = [Point(x, y) for x, y in zip(xv.ravel(), yv.ravel())]
points_gdf = gpd.GeoDataFrame(new_points, columns=['geometry'])

# Only keep points that fall within the polygon
points_in_polygon = points_gdf[points_gdf.geometry.apply(lambda point: boundary.geometry.contains(point).any())]

# Set the CRS of the points geodataframe to match the boundary's
points_in_polygon.crs = boundary.crs
points_in_polygon["name"] = points_in_polygon.reset_index().index + 1
points_in_polygon["name"] = 'pp_' + points_in_polygon["name"].astype(str)
for index, pp in points_in_polygon.iterrows():
    point = [Geometry(points_in_polygon.geometry.to_wkb()[index]).geojson["coordinates"]]
    node = g.intersect(point, "point", 0)
    points_in_polygon.loc[index, "zone"] = zone_kf[node[0][0]] + 1
points_in_polygon.to_file(os.path.join(input_directory, "vectors", 'pp.shp'))
# Out:
# /usr/local/lib/python3.8/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.8/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/lib/python3.8/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
exe_name = os.path.join("bin", "mf6")
st = os.stat(exe_name)
os.chmod(exe_name, st.st_mode | stat.S_IEXEC)

# %%
import rasterio
from rasterio.transform import from_origin
from scipy.interpolate import griddata
ws = './novgorod/model_old_pest'
model_name = 'nn'

sim = flopy.mf6.MFSimulation.load(sim_ws=ws)
m = sim.get_model(model_name)
modelgrid = m.modelgrid
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package disv...
#     loading package oc...
#     loading package obs...
#     loading package riv...
#     loading package npf...
#     loading package ic...
#     loading package rch...
#   loading solution package nn...

# %%
tdis = sim.get_package("tdis")
tdis.perioddata = [(1, 1, 1.0), (30, 6, 1.0)]
tdis.nper = 2

# %%
# storage package
sy = flopy.mf6.ModflowGwfsto.sy.empty(m, layered=True)
sy["data"] = 0.2

ss = flopy.mf6.ModflowGwfsto.ss.empty(
    m, layered=True, default_value=0.00009
)

sto = flopy.mf6.ModflowGwfsto(
    m,
    pname="sto",
    save_flows=True,
    iconvert=1,
    ss=ss,
    sy=sy,
    steady_state={0: True},
    transient={1: True},
)

# %%
# riv_pd = pd.read_csv(os.path.join(ws, "nn.riv_stress_period_data_1.txt"), header=None, sep='\s+')
# std_riv = [[(node[0] - 1, node[1] - 1), node[2], node[3]*1000000, node[4], node[5]] for node in riv_pd.values]
# riv = flopy.mf6.modflow.mfgwfriv.ModflowGwfriv(m, stress_period_data={0: std_riv, 1: [()]}, 
#                                                save_flows=True, boundnames=True)
riv = m.get_package("RIV")
riv.stress_period_data = {0: riv.stress_period_data.array[0], 1: [()]}
print(riv.stress_period_data.array[0]['cond'])
# Out:
# [ 19.66560902  18.73907748  19.67521239 ...  16.8371     428.96144558
#   91.51075   ]

# %%
riv_pd = pd.read_csv(os.path.join(ws, "nn.chd_stress_period_data_1.txt"), header=None, sep='\s+')
std_riv = [[(int(node[0] - 1), int(node[1] - 1)), node[2]] for node in riv_pd.values]
chd = flopy.mf6.ModflowGwfchd(m, stress_period_data={0:[()], 1: std_riv})
# Out:
# <>:1: DeprecationWarning: invalid escape sequence \s
# <>:1: DeprecationWarning: invalid escape sequence \s
# /tmp/ipykernel_10245/2122052269.py:1: DeprecationWarning: invalid escape sequence \s
# /tmp/ipykernel_10245/2122052269.py:1: DeprecationWarning: invalid escape sequence \s
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 riv_pd = pd.read_csv(os.path.join(ws, "nn.chd_stress_period_data_1.txt"), header=None, sep='\s+')
#       2 std_riv = [[(int(node[0] - 1), int(node[1] - 1)), node[2]] for node in riv_pd.values]
#       3 chd = flopy.mf6.ModflowGwfchd(m, stress_period_data={0:[()], 1: std_riv})
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1679, in TextFileReader._make_engine(self, f, engine)
#    1676     raise ValueError(msg)
#    1678 try:
# -> 1679     return mapping[engine](f, **self.options)
#    1680 except Exception:
#    1681     if self.handles is not None:
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File /usr/local/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:557, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
# Write the datasets
sim.exe_name = exe_name
sim.set_all_data_external(True)
sim.write_simulation()
# Run the simulation
success, buff = sim.run_simulation()
if success:
    for line in buff:
        print(line)
else:
    raise ValueError("Failed to run.")
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package nn...
#   writing model nn...
#     writing model name file...
#     writing package disv...
#     writing package oc...
#     writing package obs_0...
#     writing package riv_0...
#     writing package npf...
#     writing package ic...
#     writing package rch...
#     writing package sto...
#     writing package chd_0...
# INFORMATION: maxbound in ('gwf6', 'chd', 'dimensions') changed to 79669 based on size of stress_period_data
# FloPy is using the following executable to run the model: ../../bin/mf6
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                    VERSION 6.3.0 release candidate 03/08/2022
#                                ***DEVELOP MODE***
#
#    MODFLOW 6 compiled Mar 08 2022 20:13:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.5.0
#                              Build 20211109_000000
#
# This software is preliminary or provisional and is subject to
# revision. It is being provided to meet the need for timely best
# science. The software has not received final approval by the U.S.
# Geological Survey (USGS). No warranty, expressed or implied, is made
# by the USGS or the U.S. Government as to the functionality of the
# software and related material nor shall the fact of release
# constitute any such warranty. The software is provided on the
# condition that neither the USGS nor the U.S. Government shall be held
# liable for any damages resulting from the authorized or unauthorized
# use of the software.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 13:32:23
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     2    Time step:     2
#     Solving:  Stress period:     2    Time step:     3
#     Solving:  Stress period:     2    Time step:     4
#     Solving:  Stress period:     2    Time step:     5
#     Solving:  Stress period:     2    Time step:     6
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 13:32:35
#  Elapsed run time: 12.273 Seconds
#
#  Normal termination of simulation.

# %%
headfile = f"{model_name}.hds"
fname = os.path.join(ws, headfile)
hds = flopy.utils.HeadFile(fname)
head = hds.get_data(kstpkper=(5, 1))
head_st = hds.get_data(kstpkper=(0, 0))
head_dif = head - head_st
head_change = modelgrid.top - head
levels = np.arange(-10, 10, 1)

fig = plt.figure(figsize=(12, 12))

ax = fig.add_subplot(1, 1, 1)
pmv = flopy.plot.PlotMapView(modelgrid=modelgrid, ax=ax)
pmv.plot_array(head_change, alpha=0.2)
pmv.plot_grid(alpha=0.2)
contour = pmv.contour_array(head_change, levels=levels)
plt.clabel(contour, inline=True, fontsize=8, fmt='%1.0f')
# Out:
# <a list of 1053 text.Text objects>

# %%
import rasterio
from rasterio.transform import from_origin
from scipy.interpolate import griddata

boundary = gpd.read_file('novgorod/input/vectors/boundary.shp', crs=proj_string)
CRS = boundary.crs
bounds = boundary.bounds
head_change_rast = np.where(head_change <= 0.1, 0.1, head_change)
head_change_rast = np.where((head_change_rast > 0.1) & (head_change_rast<=0.7), 0.7, head_change_rast)
head_change_rast = np.where((head_change_rast > 0.7) & (head_change_rast<=1.2), 1.2, head_change_rast)
head_change_rast = np.where((head_change_rast > 1.2) & (head_change_rast<=2), 2, head_change_rast)
head_change_rast = np.where((head_change_rast > 2) & (head_change_rast<=3.2), 3.2, head_change_rast)
head_change_rast = np.where(head_change_rast > 3.2, 4, head_change_rast)
print(np.unique(head_change_rast))
range_x = bounds.maxx[0] - bounds.minx[0]
range_y = bounds.maxy[0] - bounds.miny[0]

# Calculate the number of cells for a grid cell size of 50m
num_cells_x = int(range_x / 50) 
num_cells_y = int(range_y / 50)

cell2d = m.disv.cell2d.get_data()
centroids_x = [cell[1] for cell in cell2d]
centroids_y = [cell[2] for cell in cell2d]

# Define grid_x and grid_y
gridx, gridy = np.meshgrid(np.linspace(bounds.minx[0], bounds.maxx[0], num=num_cells_x),
                           np.linspace(bounds.miny[0], bounds.maxy[0], num=num_cells_y))
transform = from_origin(gridx.min(), gridy.max(), 50, 50)
# Original coordinates
original_coords = np.array([centroids_x, centroids_y]).T  # x_coordinates and y_coordinates should be 1D arrays containing the x and y coordinates of your original data points respectively.

# Interpolate data
interpolated_data = griddata(original_coords, head_change_rast.flatten(), (gridx, gridy), method='linear')  # 'nearest', 'linear', or 'cubic' interpolation methods can be used depending on the data.

# Now use interpolated_data with rasterio
new_dataset = rasterio.open(
    "flood_zones.tif",
    'w',
    driver='GTiff',
    height=interpolated_data.shape[0],
    width=interpolated_data.shape[1],
    count=1,
    dtype=str(interpolated_data.dtype),
    nodata=np.nan,
    crs=CRS,
    transform=transform,
)
new_dataset.write(interpolated_data[::-1], 1)
new_dataset.close()
# Out:
# [0.1 0.7 1.2 2.  3.2 4. ]

# %%
import pyemu
import os
pst = pyemu.Pst(os.path.join('novgorod', 'master_glm_2', 'nn_pp.pst'))
pst.parrep(os.path.join('novgorod', 'master_glm_2', 'nn_pp.par'))
pst.control_data.noptmax = 0
pst.write(os.path.join(os.path.join('novgorod', 'master_glm_2'), 'nn_pp1.pst'))
pyemu.os_utils.run("pestpp-glm nn_pp1.pst", cwd=os.path.join('novgorod', 'master_glm_2'))
# Out:
# Updating parameter values from novgorod/master_glm_2/nn_pp.par
# parrep: updating noptmax to 0
# noptmax:0, npar_adj:350, nnz_obs:199
#
#
#              pestpp-glm: a tool for GLM parameter estimation and FOSM uncertainty analysis
#
#                                    by The PEST++ Development Team
#
#
# version: 5.2.5
# binary compiled on Jun 29 2023 at 04:49:25
#
# started at 10/13/23 13:05:52
# ...processing command line: ' ./pestpp-glm nn_pp1.pst'
# ...using serial run manager
#
# using control file: "nn_pp1.pst"
#
# in directory: "/app/novgorod/master_glm_2"
# on host: "504ae47f4c4c"
#
# processing control file nn_pp1.pst
#
# Note: 'NOPTMAX' == 0, switching to forgiveness mode when checking inputs
#
# Note: 3 unused lines in pest control file, see rec file...
# noptmax = 0, resetting max_run_fail = 1
# parameter warning: 78 parameters are at lower bound
# parameter warning: 160 parameters are at upper bound
# checking model IO files...done
#               starting serial run manager ...
#
#
#
#
#
#
#     ---  starting serial run manager for 1 runs ---
#
#
# 10/13/23 13:05:52 processing template files with 1 threads...
# thread 0 processed 1 template files
# 10/13/23 13:05:52 done, took 0.008 seconds
# 10/13/23 13:05:52 calling forward run command(s)
# 10/13/23 13:05:52 calling forward run command: 'python forward_run.py'
#
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.4.2 06/28/2023
#
#    MODFLOW 6 compiled Jul 05 2023 20:29:14 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 13:05:55
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2023/10/13 13:05:59
#  Elapsed run time:  3.929 Seconds
#
#  Normal termination of simulation.
# error removing tmp file:nn.obs.head.csv
# starting list mlt 2023-10-13 13:05:53.197952
# number of chunks to process: 1
# process 0  processed  0 process_list_file calls
# finished list mlt 2023-10-13 13:05:53.198068
# starting fac2real 2023-10-13 13:05:53.198078
# number of chunks to process: 1
# process 0  processed  1 fac2real calls
# finished fac2real 2023-10-13 13:05:54.633444
# starting arr mlt 2023-10-13 13:05:54.633454
# number of chunks to process: 1
# process 0  processed  1 process_array_file calls
# finished arr mlt 2023-10-13 13:05:55.102599
# 10/13/23 13:05:59 foward run command(s) finished, took 6.913 seconds
# 10/13/23 13:05:59 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 10/13/23 13:05:59 done, took 0 seconds
#
#
# -->10/13/23 13:05:59 run complete, took: 6.923 seconds
# -->1 of 1 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     1 of 1 complete, 0 failed
#     process took : 6.923 seconds
#
#
#
#
#
# -----------------------------------------
#      ---   OPTIMIZATION COMPLETE   ---
#   Reason for terminating PEST++ simulation: NOPTMAX criterion met
#   Summary of termination criteria:
#   NOPTMAX = 0 ;  NOPT at termination = 0
#   NPHINORED = 3 ;  NPHINORED at termination = 0
#   NRELPAR = 3; RELPARSTP = 0.01 ;  NRELPAR at termination = 0
#   PHIREDSTP = 0.01; NPHISTP = 3
#   NPHISTP lowest PHI's:
#
# FINAL OPTIMISATION RESULTS
#
#   Final phi                                           Total : 8460.37
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_0" : 2.98166
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_100" : 0.330826
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_101" : 18.1764
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_102" : 49.9112
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_103" : 77.4448
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_104" : 1.48233
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_105" : 3.24898
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_110" : 21.4545
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_112" : 2.35486
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_119" : 2.41752
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_120" : 47.9453
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_121" : 130.617
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_12" : 1.23272
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_150" : 306.689
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_151" : 20.2951
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_152" : 14.9591
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_156" : 30.9799
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_158" : 6.5442
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_159" : 6.34393
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_160" : 44.5176
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_161" : 0.183053
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_163" : 7.68483
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_165" : 4.9633
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_16" : 44.9952
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_170" : 2.98545
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_174" : 41.8051
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_175" : 16.647
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_178" : 10.9417
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_179" : 19.3409
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_181" : 8.75159e-05
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_182" : 88.6009
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_183" : 6.42748
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_186" : 116.643
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_187" : 52.2197
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_198" : 1.6279
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_19" : 0.764063
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_205" : 8.88175
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_206" : 5.24306
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_207" : 1.02758
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_20" : 0.766187
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_210" : 0.344756
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_211" : 6.07099
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_212" : 14.5491
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_214" : 0.593866
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_215" : 5.78957
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_217" : 1.4869
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_219" : 21.1951
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_21" : 2.45951
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_220" : 0.241812
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_222" : 3.52226
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_223" : 37.0028
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_226" : 203.371
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_22" : 138.563
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_234" : 10.081
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_235" : 46.6581
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_236" : 18.2183
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_238" : 87.9939
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_240" : 11.005
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_241" : 23.7345
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_242" : 11.0315
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_243" : 15.5456
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_246" : 0.93876
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_247" : 34.4793
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_249" : 13.5052
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_24" : 16.2637
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_253" : 76.1396
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_254" : 27.0824
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_258" : 4.26272
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_25" : 7.24242
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_262" : 15.2372
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_265" : 2.35766
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_266" : 6.77887
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_267" : 201.536
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_270" : 46.5512
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_271" : 31.1958
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_272" : 55.0411
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_274" : 81.4216
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_276" : 4.45387
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_279" : 7.63079
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_27" : 9.66419
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_280" : 203.191
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_281" : 128.881
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_283" : 31.2485
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_284" : 0.0701575
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_288" : 8.55505
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_291" : 207.77
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_296" : 80.5796
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_297" : 118.592
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_302" : 98.8494
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_303" : 3.05894
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_305" : 13.9258
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_311" : 59.3925
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_312" : 0.0460219
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_316" : 19.6509
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_31" : 112.995
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_326" : 134.803
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_328" : 297.517
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_329" : 2.03245
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_330" : 34.7357
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_331" : 11.0486
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_333" : 39.149
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_335" : 146.391
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_339" : 3.28812
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_340" : 10.6608
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_341" : 45.7105
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_343" : 37.1111
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_345" : 127.898
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_347" : 82.675
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_353" : 76.008
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_382" : 1.20097
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_386" : 66.7601
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_389" : 78.613
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_390" : 4.0148
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_392" : 34.045
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_394" : 101.891
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_406" : 51.3716
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_411" : 228.153
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_413" : 80.2284
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_414" : 3.58966
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_417" : 18.6158
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_422" : 20.8709
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_427" : 84.9544
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_429" : 33.304
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_430" : 8.07878
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_434" : 4.65235
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_435" : 14.821
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_438" : 41.4186
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_440" : 2.13889
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_445" : 0.13053
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_451" : 2.95166
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_454" : 0.0136377
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_456" : 162.582
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_457" : 18.1039
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_462" : 0.15448
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_464" : 65.8981
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_466" : 2.36617
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_467" : 59.8916
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_483" : 0.151022
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_484" : 17.2911
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_486" : 1.47281
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_488" : 6.97987
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_497" : 208.205
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_498" : 358.825
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_49" : 6.31585
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_501" : 134.531
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_502" : 15.0056
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_503" : 8.34507
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_504" : 96.3154
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_505" : 74.4507
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_508" : 0.323741
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_509" : 47.431
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_510" : 52.9949
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_511" : 4.32536
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_512" : 13.5008
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_513" : 25.6175
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_514" : 138.374
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_515" : 3.444
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_516" : 13.2501
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_517" : 1.0967
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_519" : 9.91433
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_51" : 18.3313
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_521" : 26.7433
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_522" : 8.68354
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_526" : 75.9098
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_53" : 1.97333
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_544" : 0.0140549
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_545" : 0.411945
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_546" : 3.37272
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_54" : 2.18251
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_550" : 14.818
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_551" : 9.65258
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_555" : 7.64936
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_55" : 37.6726
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_56" : 7.35943
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_589" : 14.3907
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_58" : 3.98262
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_590" : 0.423246
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_591" : 1.4587
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_592" : 21.9689
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_5" : 4.57507
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_614" : 33.9341
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_61" : 5.12198
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_624" : 5.87354
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_625" : 30.7404
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_626" : 3.74633
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_62" : 1.95624
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_63" : 2.75055
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_64" : 5.55168
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_65" : 13.5104
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_66" : 23.7582
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_70" : 2.53313
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_73" : 211.924
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_74" : 235.856
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_75" : 273.506
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_83" : 0.227825
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_85" : 256.829
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_94" : 1.11519
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_95" : 1.7057
#   Contribution to phi from observation group "oname:hds_otype:lst_usecol:h_96" : 0.427683
#
#
# pestpp-glm analysis complete...
# started at 10/13/23 13:05:52
# finished at 10/13/23 13:05:59
# took 0.1 minutes
